# %%
Name:Farhan Samir Ibushe Roll no:3063 Urn no:23031115

# %%
n=int(input("Enter number"))
def prime(n):
    if n<2:
        print("Number is not prime")
    flag=False
    for i in range(2,n-1):
        if n%i==0:
            flag=True
            break;
    if flag:
        print("Not Prime")
    else:
        print("Prime")
prime(n)
# Out:
# Enter number 23
# Prime

# %%
import numpy as np
arr=np.array([1,2,3,4,5,6,7])
print("Original array",arr)
print("Array sqaure",arr*arr)
# Out:
# Original array [1 2 3 4 5 6 7]
# Array sqaure [ 1  4  9 16 25 36 49]

# %%
import pandas as pd
data={"Name":["Farhan","Rehan","Parshwaraj","Parth"],"Age":[21,21,21,21]}
df=pd.DataFrame(data)
print(df)
# Out:
#          Name  Age
# 0      Farhan   21
# 1       Rehan   21
# 2  Parshwaraj   21
# 3       Parth   21

# %%
df['Address']=['Islampur','Ashta','Karad','Sangli']
print(df)
# Out:
#          Name  Age   Address
# 0      Farhan   21  Islampur
# 1       Rehan   21     Ashta
# 2  Parshwaraj   21     Karad
# 3       Parth   21    Sangli

# %%
import matplotlib.pyplot as plt
plt.bar(df['Name'],df['Age'])
plt.xlabel("Name")
plt.ylabel("Age")
plt.title("MyData")
plt.show()

# %%
plt.pie(df['Age'],labels=df['Name'])
plt.show()

# %%
import numpy as np
arr1=np.array([[3,2],[6,5]])
arr2=np.array([[7,8],[7,5]])
arr3=np.dot(arr1,arr2)
print(arr3)
# Out:
# [[35 34]
#  [77 73]]
